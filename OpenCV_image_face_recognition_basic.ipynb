# %%
#mounting google drive
from google.colab import drive
drive.mount('/content/drive')
import os
import cv2
from google.colab.patches import cv2_imshow
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
image = cv2.imread('/content/drive/My Drive/group-image.jpg')
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=621x360>

# %%
face_cascade = cv2.CascadeClassifier('/content/drive/My Drive/haarcascade_frontalface_default.xml')
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
faces = face_cascade.detectMultiScale(gray_image, 1.1, 4)

print(f"Number of faces detected: {len(faces)}")

#drawing a ractangle
for(x,y,w,h) in faces:
  cv2.rectangle(image,(x,y),(x+w,y+h),(255,0,0),2)

cv2_imshow(image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Number of faces detected: 5
# <PIL.Image.Image image mode=RGB size=621x360>
